# %%
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as stats
from collections import Counter
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import MACCSkeys
from rdkit.Chem import DataStructs
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.SimDivFilters.rdSimDivPickers import MaxMinPicker
from itertools import product, compress
from sklearn.svm import SVC
from sklearn.feature_selection import SelectPercentile, SelectKBest
from sklearn.feature_selection import chi2, mutual_info_classif
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import auc, roc_curve
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from tensorboard.plugins.hparams import api as hp
from sklearn.model_selection import train_test_split
matplotlib.rcParams.update({'font.size': 24})
plt.style.use("ggplot")

PATH_DATA = "../datasets/SARS2/"
PATH_DATA_GHDDI = "../datasets/SAR1/GHDDI"

# %%
def get_features_RDKIT(input_sdf):
    structures_shared = Chem.SDMolSupplier(input_sdf)
    features = {}
    fps = {}
    mols = {}
    error_mols = 0
    mol_names = set()
    for mol in structures_shared:
        if mol is None:
            error_mols += 1
            continue
        if mol.GetProp("_Name") in mol_names:
            continue
        name = int(mol.GetProp("_Name"))
        mol_names.add(name)
        AllChem.Compute2DCoords(mol)
        key = Chem.inchi.MolToInchiKey(mol)
        if (name, key) not in features:
            fp = Chem.RDKFingerprint(mol)           
            fps[(name, key)] = fp
            mols[(name, key)] = mol
            arr = np.zeros((0,), dtype=np.int8)
            DataStructs.ConvertToNumpyArray(fp,arr)
            # remove the first value which is added artificially
            features[(name, key)] = arr
    print(f"Found problems in {error_mols} molecules")
    return fps, features, mols

def get_molecules_from_data(features, fps, mols, data, id_column="Molecule_ID", structure_column="Standardized_Molecule_InChIKey", smiles_columns="Standardized_Molecule_Smiles", only_exact_matches=True, threshold_similarity=0.99):
    mol_ids = data[id_column]
    keys = data[structure_column]
    filtered_features = []
    filtered_fps = []
    filtered_mols = []
    filtered_bits = []
    mask = []
    unfound_structures = Chem.SDWriter(os.path.join(PATH_DATA, "molecules_missing.sdf"))
    for id_val in zip(mol_ids, keys):
        if id_val in features:
            mask.append(True)
            filtered_features.append(features[id_val])
            filtered_fps.append(fps[id_val])
            filtered_mols.append(mols[id_val])
        else:
            similar_mols = [k for k in features if k[0] == id_val[0]]
            if not similar_mols:
                print("Could not find molecules with id", id_val[0])
                mask.append(False)
                continue
            if only_exact_matches:
                mask.append(False)
                print(id_val)
                print(similar_mols)
            else:
                fps_similars = [fps[k] for k in similar_mols]
                smiles = data[(data[id_column] == id_val[0]) & (data[structure_column] == id_val[1])][smiles_columns].values[0]
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    if len(similar_mols) == 1:
                        mask.append(True)
                        filtered_features.append(features[similar_mols[0]])
                        filtered_fps.append(fps[similar_mols[0]])
                        filtered_mols.append(mols[similar_mols[0]])
                        continue
                    else:
                        mask.append(False)
                        print("Could not create molecule", id_val, "with smiles", smiles, "most similar", similar_mols)
                        continue
                mol.SetProp("_Name", str(id_val[0]))
                fp_mol = Chem.RDKFingerprint(mol)
                similarities = [DataStructs.TanimotoSimilarity(fp_mol, fp_possible) for fp_possible in fps_similars]
                # print(id_val)
                # print("Most similar molecules:")
                # for ids, sim in zip(similar_mols, similarities):
                    # print("\t", ids, sim)
                most_similar = np.argmax(similarities)
                if similarities[most_similar] > threshold_similarity:
                    # print("Selected: ", similar_mols[most_similar], similarities[most_similar])
                    mask.append(True)
                    filtered_features.append(features[similar_mols[most_similar]])
                    filtered_fps.append(fps[similar_mols[most_similar]])
                    filtered_mols.append(mols[similar_mols[most_similar]])
                else:
                    unfound_structures.write(mol)
                    print(id_val)
                    for ids, sim in zip(similar_mols, similarities):
                        print("\t", ids, sim)
                    mask.append(False)
    return np.array(filtered_features), filtered_fps, filtered_mols, mask

def convert_IC50_to_um(data, col_values, col_units):
    new_vals = []
    for val, unit in zip(data[col_values], data[col_units]):
        if unit == "nM":
            new_vals.append(val/1000)
        elif unit == "µM":
            new_vals.append(val)
        else:
            raise ValueError(f"{unit} unit not found!")
    data[col_values] = new_vals
    data[col_units] = "µM"
    return data

def filter_duplicates(data, col_id, col_structure):
    dup = data.duplicated(subset=[col_id, col_structure], keep=False)
    to_remove = []
    for id_val in data[dup][col_id].unique():
        dup_data = data[data[col_id] == id_val]
        if len(set(dup_data["Is_active"])) != 1:
            to_remove.append(id_val)
    rm_masks = data[col_id].isin(to_remove)
    data = data[~rm_masks]
    return data, rm_masks

# %%
fps_SARS2, features_SARS2, mols_SARS2 = get_features_RDKIT(os.path.join(PATH_DATA, "SIM_Broad_MProResults_ligprep_maestro.sd"))
# Out:
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit ERROR: [18:24:41] Explicit valence for atom # 1 C greater than permitted
# RDKit ERROR: [18:24:41] ERROR: Could not sanitize molecule ending on line 15167
# RDKit ERROR: [18:24:41] ERROR: Explicit valence for atom # 1 C greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 1 C greater than permitted
# RDKit ERROR: [18:24:41] ERROR: Could not sanitize molecule ending on line 15269
# RDKit ERROR: [18:24:41] ERROR: Explicit valence for atom # 1 C greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 1 C greater than permitted
# RDKit ERROR: [18:24:41] ERROR: Could not sanitize molecule ending on line 15371
# RDKit ERROR: [18:24:41] ERROR: Explicit valence for atom # 1 C greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 1 C greater than permitted
# RDKit ERROR: [18:24:41] ERROR: Could not sanitize molecule ending on line 15473
# RDKit ERROR: [18:24:41] ERROR: Explicit valence for atom # 1 C greater than permitted
# RDKit ERROR: [18:24:41] Invalid InChI prefix in generating InChI Key
# RDKit ERROR: [18:24:41] Invalid InChI prefix in generating InChI Key
# RDKit ERROR: [18:24:41] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] ERROR: Could not sanitize molecule ending on line 17602
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit ERROR: [18:24:41] ERROR: Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 16 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] ERROR: Could not sanitize molecule ending on line 22842
# RDKit ERROR: [18:24:41] ERROR: Explicit valence for atom # 16 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 16 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] ERROR: Could not sanitize molecule ending on line 23015
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit ERROR: [18:24:41] ERROR: Explicit valence for atom # 16 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] ERROR: Could not sanitize molecule ending on line 24500
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:41] Warning: molecule is tagged as 3D, but all Z coords are zero
# Found problems in 8 molecules

# %%
threshold_activity = 20 # uM
data_orig_broad = pd.read_csv(os.path.join(PATH_DATA, "20200623_3CLpro_Hits_Broad_DOMPE_Summary-broad.csv"), decimal=",")
data_orig_dompe = pd.read_csv(os.path.join(PATH_DATA, "20200623_3CLpro_Hits_Broad_DOMPE_Summary-dompe.csv"), decimal=",")
data_orig_broad = data_orig_broad.rename(columns={"NAME": "Name",
                                                  "3CL-Pro IC50-15min (µM) (triplicates)": "IC50 µM 15 min",
                                                  "3CLpro\n IC50 slope (µM) (triplicates)": "IC50 µM slope"})
data_orig_dompe = data_orig_dompe.rename(columns={"IC50 µM\n 15 min\n (red manually confirmed)": "IC50 µM 15 min",
                                                  "IC50 µM\n slope\n (red manually confirmed)": "IC50 µM slope"})
data_SARS2 = pd.concat([data_orig_broad, data_orig_dompe])

correspondance_broad = pd.read_csv(os.path.join(PATH_DATA, "DOMPE_Broad_MProResults_IDCorrespondence_broad.csv"), decimal=",")
correspondance_broad = correspondance_broad.rename(columns={"Molecule_id": "Molecule_ID"})
correspondance_dompe = pd.read_csv(os.path.join(PATH_DATA, "DOMPE_Broad_MProResults_IDCorrespondence_dompe.csv"), decimal=",")
correspondance = pd.concat([correspondance_broad, correspondance_dompe])
correspondance = correspondance.rename(columns={"Fraunofer Compound Id": "Compound Id"})
data_SARS2 = data_SARS2.merge(correspondance, how="inner", on="Compound Id")

# %%
data_SARS2["Is_active"] = (data_SARS2["IC50 µM 15 min"] < threshold_activity).values.astype(int)
print(data_SARS2.shape)
# Out:
# (191, 32)

# %%
dup = data_SARS2.duplicated(subset=["Molecule_ID", "Standardized_Molecule_InChIKey"], keep="first")
print(f"Found {sum(dup)} duplicated entries")
all_dup = data_SARS2.duplicated(subset=["Molecule_ID", "Standardized_Molecule_InChIKey"], keep=False)
data_SARS2 = data_SARS2[~dup]
print(data_SARS2.shape)
# Out:
# Found 10 duplicated entries
# (181, 32)

# %%
data_SARS2[all_dup]
# Out:
# /home/jfrancesc/miniconda3/envs/drug_learning/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        Compound Id                          Name  \
# 8    SPE_K81330143                    Tideglusib
# 9    SPE_K34149328                   bonaphthone
# 30   SPE_K86972824                      OLTIPRAZ
# 33   SPE_K55591206  (-)-Epigallocatechin Gallate
# 38   SPE_K68408467        PROFLAVINE HEMISULFATE
# 58   SPE_M87138257     Acriflavine hydrochloride
# 74   SPE_K20313525               rosmarinic-acid
# 95   SPE_A49172652                  LANSOPRAZOLE
# 112  SPE_K76841105            Tazarotene (Avage)
# 137  SPE_K33623053       Rose Bengal Sodium Salt
#
#     DTT sensitivity (if > 30 % loss of activity at 20 µM)  \
# 8                                             sensitiv
# 9                                             sensitiv
# 30                                            sensitiv
# 33                                            sensitiv
# 38                                            sensitiv
# 58                           Acriflavine hydrochloride
# 74                                            sensitiv
# 95                                            sensitiv
# 112                                 Tazarotene (Avage)
# 137                            Rose Bengal Sodium Salt
#
#      Inhibition [%] Primary Screen (single point; 20 µM)  \
# 8                                                90.94
# 9                                                95.47
# 30                                               93.83
# 33                                               95.26
# 38                                               60.89
# 58                                               59.00
# 74                                               95.67
# 95                                               97.15
# 112                                            -880.10
# 137                                              99.60
#
#      HC\nInhibition [%] (triplicate, 20 µM)  \
# 8                                     99.30
# 9                                     99.37
# 30                                    97.56
# 33                                    98.89
# 38                                    76.55
# 58                                    67.97
# 74                                    94.92
# 95                                    98.57
# 112                                 -692.49
# 137                                   74.85
#
#      HC\n AV Inhibition [%] (triplicate, 20 µM)\nslope  \
# 8                                                99.28
# 9                                               100.31
# 30                                              101.75
# 33                                               97.04
# 38                                               99.87
# 58                                               99.10
# 74                                               94.14
# 95                                               96.07
# 112                                             108.07
# 137                                              -2.27
#
#      AV inhibition +DTT 15min \nduplicates  IC50 µM 15 min  IC50 µM slope  \
# 8                                    -4.89            0.15           0.14
# 9                                    37.44            0.16           0.38
# 30                                    1.56            0.62           1.44
# 33                                  -22.36            0.72           1.29
# 38                                   20.41            0.83           2.02
# 58                                   68.22            1.93           5.10
# 74                                  -17.76            3.86           4.96
# 95                                  -12.10            7.25          10.83
# 112                                -663.39           13.50         321.75
# 137                                  69.98         1176.55          26.97
#
#      %inhibition_d03-KU_LW  ...  AV Inhibiton\n 15min %Inhibition\n_slope PS  \
# 8                    -3.46  ...                   NaN                    NaN
# 9                    -1.01  ...                   NaN                    NaN
# 30                    6.11  ...                   NaN                    NaN
# 33                   -1.41  ...                   NaN                    NaN
# 38                   19.09  ...                   NaN                    NaN
# 58                  -26.74  ...                   NaN                    NaN
# 74                    8.26  ...                   NaN                    NaN
# 95                    1.65  ...                   NaN                    NaN
# 112                  -2.40  ...                   NaN                    NaN
# 137                  22.43  ...                   NaN                    NaN
#
#     %Inhibition\n_15min PS VeroE6% \nConfluence_d03 VeroE6 % \nInhibition_d03  \
# 8                      NaN                      NaN                       NaN
# 9                      NaN                      NaN                       NaN
# 30                     NaN                      NaN                       NaN
# 33                     NaN                      NaN                       NaN
# 38                     NaN                      NaN                       NaN
# 58                     NaN                      NaN                       NaN
# 74                     NaN                      NaN                       NaN
# 95                     NaN                      NaN                       NaN
# 112                    NaN                      NaN                       NaN
# 137                    NaN                      NaN                       NaN
#
#     Chemically reactive? Molecule_ID Standardized_Molecule_InChIKey  \
# 8                    NaN        3878    PMJIHLSCWIDGMD-UHFFFAOYSA-N
# 9                    NaN        4448    MXWZRRPNVLCHMY-UHFFFAOYSA-N
# 30                   NaN        8437    CKNAQFVBEHDJQV-UHFFFAOYSA-N
# 33                   NaN         522    WMBWREPUVVBILR-WIYYLYMNSA-N
# 38                   NaN        6835    WDVSHHCDHLJJJR-UHFFFAOYSA-N
# 58                   NaN        6864    NLROCEWTIPMDKX-UHFFFAOYSA-N
# 74                   NaN        8605    DOUMFZQKYFQNTF-WUTVXBCWSA-N
# 95                   NaN         348    MJIHNNLFOKEZEW-UHFFFAOYSA-N
# 112                  NaN         445    OGQICQVSFDPSEI-UHFFFAOYSA-N
# 137                  NaN        5272    IICCLYANAQEHCI-UHFFFAOYSA-N
#
#                           Standardized_Molecule_Smiles  Is_active
# 8               O=C1SN(C(=O)N1Cc2ccccc2)c3cccc4ccccc34          1
# 9                            Brc1ccc2C(=O)C(=O)C=Cc2c1          1
# 30                               CC1=C(SSC1=S)c2cnccn2          1
# 33   Oc1cc(O)c2C[C@@H](OC(=O)c3cc(O)c(O)c(O)c3)[C@H...          1
# 38                            Nc1ccc2cc3ccc(N)cc3nc2c1          1
# 58                   C[N]1=C2C=C(N)C=CC2=Cc3ccc(N)cc13          1
# 74   OC(=O)[C@@H](Cc1ccc(O)c(O)c1)OC(=O)\C=C\c2ccc(...          1
# 95         Cc1c(OCC(F)(F)F)ccnc1CS(=O)c2nc3ccccc3[nH]2          1
# 112          CCOC(=O)c1ccc(nc1)C#Cc2ccc3SCCC(C)(C)c3c2          1
# 137  Oc1c(I)cc2c(Oc3c(I)c(O)c(I)cc3C24OC(=O)c5c(Cl)...          0
#
# [10 rows x 32 columns]

# %%
features_SARS2, fps_SARS2, mols_SARS2, mask = get_molecules_from_data(features_SARS2, fps_SARS2, mols_SARS2, data_SARS2, only_exact_matches=False, threshold_similarity=0.2)
data_filtered = data_SARS2[mask]
active_SARS2 = data_filtered["Is_active"].values
print(sum(mask))
# Out:
# Could not find molecules with id 11947
# Could not find molecules with id 12210
# Could not find molecules with id 10107
# Could not find molecules with id 7168
# (6835, 'WDVSHHCDHLJJJR-UHFFFAOYSA-N')
# 	 (6835, 'IHRJICSCSWHANS-UHFFFAOYSA-N') 0.14022988505747128
# Could not find molecules with id 11215
# Could not find molecules with id 10484
# Could not find molecules with id 10913
# Could not find molecules with id 12105
# Could not find molecules with id 11495
# Could not find molecules with id 6326
# Could not find molecules with id 10781
# Could not find molecules with id 11917
# Could not find molecules with id 10766
# Could not find molecules with id 12364
# (10817, 'PSFDQSOCUJVVGF-UHFFFAOYSA-N')
# 	 (10817, 'FLJHILGVZZUAHY-UHFFFAOYSA-N') 0.1834862385321101
# RDKit ERROR: [18:24:41] ERROR: Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 16 N, 4, is greater than permitted
# RDKit ERROR: [18:24:41] Explicit valence for atom # 3 N, 4, is greater than permitted
# 165

# %% [markdown]
# Load GHDDI data set

# %%
data_GHDDI_orig = pd.read_csv(os.path.join(PATH_DATA_GHDDI, "3CLProtease_ActiveDataset.csv"), decimal=",")
activity_col = "value_GHDDI"
measures_col = "parameter_GHDDI"
units_col = "unit_GHDDI"
id_col = "Molecule_ID"

# %%
data_GHDDI = data_GHDDI_orig.dropna(subset=[activity_col, id_col]).copy()
data_GHDDI[id_col] = data_GHDDI[id_col].astype(int)
data_GHDDI = data_GHDDI[data_GHDDI[measures_col] == "IC50"]
dup = data_GHDDI.duplicated(subset=["Molecule_ID", "Standardized_Molecule_InChIKey"], keep="first")
print(f"Found {sum(dup)} duplicated entries")
data_GHDDI = data_GHDDI[~dup]
data_GHDDI.shape
# Out:
# Found 0 duplicated entries
# (401, 33)

# %% [markdown]
# Convert all experimental values to micromolar

# %%
data_GHDDI = convert_IC50_to_um(data_GHDDI, activity_col, units_col)
data_GHDDI["Is_active"] = (data_GHDDI[activity_col] < threshold_activity).values.astype(int)

# %%
fps_rdkit_GHDDI, features_rdkit_GHDDI, mols_rdkit_GHDDI = get_features_RDKIT(os.path.join(PATH_DATA_GHDDI, "3C-like_protease_GHDDI_ligprep_maestro.sdf"))
# Out:
# RDKit WARNING: [18:24:42] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit ERROR: [18:24:42] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [18:24:42] ERROR: Could not sanitize molecule ending on line 11557
# RDKit WARNING: [18:24:42] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit ERROR: [18:24:42] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [18:24:42] Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] ERROR: Could not sanitize molecule ending on line 85833
# RDKit ERROR: [18:24:42] ERROR: Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] ERROR: Could not sanitize molecule ending on line 86055
# RDKit ERROR: [18:24:42] ERROR: Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] ERROR: Could not sanitize molecule ending on line 86277
# RDKit ERROR: [18:24:42] ERROR: Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] ERROR: Could not sanitize molecule ending on line 86499
# RDKit ERROR: [18:24:42] ERROR: Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] ERROR: Could not sanitize molecule ending on line 86721
# RDKit ERROR: [18:24:42] ERROR: Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] ERROR: Could not sanitize molecule ending on line 86943
# RDKit ERROR: [18:24:42] ERROR: Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:42] ERROR: Could not sanitize molecule ending on line 87165
# RDKit WARNING: [18:24:42] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:43] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:43] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:43] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:43] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:43] Warning: molecule is tagged as 3D, but all Z coords are zero
# Found problems in 8 molecules
# RDKit WARNING: [18:24:43] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [18:24:43] Warning: molecule is tagged as 3D, but all Z coords are zero

# %%
features_GHDDI, fps_GHDDI, mols_GHDDI, mask_GHDDI = get_molecules_from_data(features_rdkit_GHDDI, fps_rdkit_GHDDI, mols_rdkit_GHDDI, data_GHDDI, only_exact_matches=False, threshold_similarity=0.2)
data_GHDDI = data_GHDDI[mask_GHDDI]
active_SARS1 = data_GHDDI["Is_active"].values
print(data_GHDDI.shape, sum(mask_GHDDI))
# Out:
# RDKit ERROR: [18:24:42] ERROR: Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [18:24:43] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [18:24:43] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [18:24:43] Explicit valence for atom # 8 N, 4, is greater than permitted
# Could not find molecules with id 9602
# RDKit ERROR: [18:24:43] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [18:24:43] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [18:24:43] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [18:24:43] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [18:24:43] Explicit valence for atom # 6 N, 4, is greater than permitted
# RDKit ERROR: [18:24:43] Explicit valence for atom # 16 N, 4, is greater than permitted
# RDKit ERROR: [18:24:43] Explicit valence for atom # 9 N, 4, is greater than permitted
# (400, 34) 400

# %%
sources = ["SARS2" for _ in fps_SARS2]+["SARS1" for _ in fps_GHDDI]
joined_sets = pd.concat([data_filtered, data_GHDDI], ignore_index=True)
joined_features = np.vstack((features_SARS2, features_GHDDI))
joined_fps = fps_SARS2+fps_GHDDI
joined_mols = mols_SARS2+mols_GHDDI
joined_sets, mask_to_rm = filter_duplicates(joined_sets, id_col, "Standardized_Molecule_InChIKey")
joined_features = joined_features[~mask_to_rm]
joined_fps = list(compress(joined_fps, ~mask_to_rm))
joined_mols = list(compress(joined_mols, ~mask_to_rm))
joined_sources = list(compress(sources, ~mask_to_rm))
active = joined_sets["Is_active"].values
fw = Chem.SDWriter(os.path.join(PATH_DATA, "molecules_cleaned_SARS1_SARS2_rdkit.sdf"))
for mol in joined_mols:
    fw.write(mol)
joined_sets.to_csv(os.path.join(PATH_DATA, "dataset_cleaned_SARS1_SARS2_rdkit.csv"), index=False)
np.save(os.path.join("features", "SARS1_SARS2", "RDKIT.npy"), joined_features)
np.save(os.path.join("features", "SARS2", "RDKIT.npy"), features_SARS2)
np.save(os.path.join("features", "SARS1", "RDKIT.npy"), features_GHDDI)
print(joined_sets.shape, len(joined_fps), len(joined_mols), joined_features.shape)
# Out:
# (563, 62) 563 563 (563, 2048)

# %%
plt.figure(figsize=(8,8))
plt.hist(active, bins=10);
plt.xticks([0.05, 0.95], ["Inactives", "Actives"])
n_active = sum(active)
n_inactive = len(active)-n_active
print(f"Actives {n_active}, {100*n_active/(n_active+n_inactive):.2f}%; Inactives {n_inactive}, {100*n_inactive/(n_active+n_inactive):.2f}%")
# Out:
# Actives 310, 55.06%; Inactives 253, 44.94%

# %%
def print_metrics(predicted_values, target_values, verbose=True):
    tn, fp, fn, tp = confusion_matrix(target_values, predicted_values >= 0.5).ravel()
    Sn = tp/(tp+fn)
    Sp = tn/(tn+fp)
    precision = tp/(tp+fp)
    ner = (Sn+Sp)/2
    accuracy = (tp+tn)/(tp+tn+fp+fn)
    mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
    if verbose:
        print(f"NER: {ner:.3f}, Sensitivity or recall: {Sn:.3f}, Specificity: {Sp:.3f}, Precision: {precision:.3f}, Correctly classified: {accuracy:.3f}, MCC: {mcc:.3f}")
    return [accuracy, mcc]

def plot_confusion(predicted_values, target_values):
    cm = confusion_matrix(target_values, predicted_values >= 0.5)
    f, ax = plt.subplots(1, 1)
    sns.heatmap(cm, annot=True, ax = ax, fmt="g", cmap="Greens")
    # labels, title and ticks
    ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
    ax.set_title('Confusion Matrix'); 
    ax.xaxis.set_ticklabels(['Inactive', 'Active']); ax.yaxis.set_ticklabels(['Inactive', 'Active'])
    plt.show()
    
def grid_search_SVM(train_data, test_data, train_labels, test_labels, max_gamma=1, min_gamma=0.001, max_C=100, min_C=0.01, n_points=30):
    accuracy = []
    MCCs = []
    C_values = np.geomspace(min_C, max_C, num=n_points)
    gamma_values = np.geomspace(min_gamma, max_gamma, num=n_points)
    for c_val in C_values:
        acc = []
        mcc = []
        for gamma in gamma_values:
            svm = SVC(C=c_val, kernel="rbf", gamma=gamma)
            svm.fit(train_data, train_labels)
            predictions = svm.predict(test_data)
            print(f"C={c_val}, gamma={gamma}")
            vals = print_metrics(predictions, test_labels)
            acc.append(vals[0])
            mcc.append(vals[1])
        accuracy.append(acc)
        MCCs.append(mcc)

    fig, ax = plt.subplots(figsize=(8, 8))
    sns.heatmap(MCCs, annot=False, ax = ax, cmap="Greens")
    ax.set_yticklabels(np.round(C_values, 2), rotation=0)
    ax.set_xticklabels(np.round(gamma_values, 2), rotation=90)
    ax.set_ylabel("C value")
    ax.set_xlabel(r"$\gamma$")
    plt.show()

# %%
train_data, test_data, train_labels, test_labels = train_test_split(joined_features, active, test_size=0.25, random_state=42, stratify=active)

# %%
clf = DecisionTreeClassifier(random_state=42, class_weight="balanced")
clf.fit(train_data, train_labels)
predictions = clf.predict(test_data)
vals = print_metrics(predictions, test_labels)
plot_confusion(predictions, test_labels)
# Out:
# NER: 0.713, Sensitivity or recall: 0.808, Specificity: 0.619, Precision: 0.724, Correctly classified: 0.723, MCC: 0.436

# %%
order_dt = np.argsort(clf.feature_importances_)[::-1]
x = np.array(range(len(clf.feature_importances_)))[:20]
plt.bar(x, clf.feature_importances_[order_dt][:20])
plt.xticks(x, order_dt[:20], rotation=90);
plt.xlabel("Feature index")
plt.ylabel("Importance")
plt.title("Decision tree");

# %%
clf = RandomForestClassifier(random_state=42, class_weight="balanced")
clf.fit(train_data, train_labels)
predictions = clf.predict(test_data)
vals = print_metrics(predictions, test_labels)
plot_confusion(predictions, test_labels)
# Out:
# NER: 0.760, Sensitivity or recall: 0.885, Specificity: 0.635, Precision: 0.750, Correctly classified: 0.773, MCC: 0.542

# %%
order_RF = np.argsort(clf.feature_importances_)[::-1]
x = np.array(range(len(clf.feature_importances_)))[:20]
plt.bar(x, clf.feature_importances_[order_RF][:20])
plt.xticks(x, order_RF[:20], rotation=90);
plt.xlabel("Feature index")
plt.ylabel("Importance")
plt.title("Random Forests");

# %%
# come from highest correlation to labels using chi-2 and mutual information
best = list(set(order_dt[:20]) & set(order_RF[:20]))
print(best)
# Out:
# [449]

# %% [markdown]
# We test a similar approach with the SARS2 data set only

# %%
train_data2, test_data2, train_labels2, test_labels2 = train_test_split(features_SARS2, active_SARS2, test_size=0.25, random_state=42, stratify=active_SARS2)

# %%
plt.figure(figsize=(4,4))
plt.hist(active_SARS2, bins=10);
plt.xticks([0, 1], ["Inactive", "Active"]);

# %%
C= 7.8804628
gamm = 0.02807
svm = SVC(C=C, kernel="rbf", gamma=gamm, class_weight="balanced")
svm.fit(train_data2, train_labels2)
predictions = svm.predict(test_data2)
vals = print_metrics(predictions, test_labels2)
plot_confusion(predictions, test_labels2)
# Out:
# NER: 0.542, Sensitivity or recall: 1.000, Specificity: 0.083, Precision: 0.732, Correctly classified: 0.738, MCC: 0.247

# %% [markdown]
# Try with the SARS1 data set only

# %%
train_data1, test_data1, train_labels1, test_labels1 = train_test_split(features_GHDDI, active_SARS1, test_size=0.25, random_state=42, stratify=active_SARS1)

# %%
plt.figure(figsize=(4,4))
plt.hist(active_SARS1, bins=10);
plt.xticks([0, 1], ["Inactive", "Active"]);

# %%
C= 4.17531
gamm = 0.02807
svm = SVC(C=C, kernel="rbf", gamma=gamm, class_weight="balanced")
svm.fit(train_data1, train_labels1)
predictions = svm.predict(test_data1)
vals = print_metrics(predictions, test_labels1)
plot_confusion(predictions, test_labels1)
# Out:
# NER: 0.757, Sensitivity or recall: 0.592, Specificity: 0.922, Precision: 0.879, Correctly classified: 0.760, MCC: 0.546

# %% [markdown]
# Train with SARS1, test with SARS2

# %%
C= 8.53
gamm = 0.05
svm = SVC(C=C, kernel="rbf", gamma=gamm, class_weight="balanced")
svm.fit(features_GHDDI, active_SARS1)
predictions = svm.predict(features_SARS2)
vals = print_metrics(predictions, active_SARS2)
plot_confusion(predictions, active_SARS2)
# Out:
# NER: 0.500, Sensitivity or recall: 0.000, Specificity: 1.000, Precision: nan, Correctly classified: 0.297, MCC: nan
# <ipython-input-39-d75c9e15214a>:5: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp/(tp+fp)
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))

# %% [markdown]
# Similar but adding class weights

# %%
C= 8.53
gamm = 0.05
svm = SVC(C=C, kernel="rbf", gamma=gamm, class_weight="balanced")
svm.fit(features_GHDDI, active_SARS1)
predictions = svm.predict(features_SARS2)
vals = print_metrics(predictions, active_SARS2)
plot_confusion(predictions, active_SARS2)
# Out:
# NER: 0.500, Sensitivity or recall: 0.000, Specificity: 1.000, Precision: nan, Correctly classified: 0.297, MCC: nan
# <ipython-input-39-d75c9e15214a>:5: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp/(tp+fp)
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))

# %% [markdown]
# Train with SARS2, test with SARS1

# %%
C= 1.172102
gamm = 0.0239
svm = SVC(C=C, kernel="rbf", gamma=gamm)
svm.fit(features_SARS2, active_SARS2)
predictions = svm.predict(features_GHDDI)
vals = print_metrics(predictions, active_SARS1)
plot_confusion(predictions, active_SARS1)
# Out:
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.487, Correctly classified: 0.487, MCC: nan

# %%
C= 1.172102
gamm = 0.0239
svm = SVC(C=C, kernel="rbf", gamma=gamm, class_weight="balanced")
svm.fit(features_SARS2, active_SARS2)
predictions = svm.predict(features_GHDDI)
vals = print_metrics(predictions, active_SARS1)
plot_confusion(predictions, active_SARS1)
# Out:
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.487, Correctly classified: 0.487, MCC: nan

# %% [markdown]
# Try 10-fold cross validation with the full data set

# %%
def run_cross_validation(features, labels, folds=5, iters=10, clf=RandomForestClassifier(random_state=42, class_weight="balanced"), verbose=True):
    MCCs_val = []
    MCCs_test = []
    accs_val = []
    accs_test = []
    for i in range(iters):
        training_set, testing_set, training_labels, testing_labels = train_test_split(features, labels, test_size=0.25, random_state=i, stratify=labels)
        skf = StratifiedKFold(n_splits=folds)
        for i, (train_index, test_index) in enumerate(skf.split(training_set, training_labels)):
            train_data, val_data = training_set[train_index], training_set[test_index]
            train_labels, val_labels = training_labels[train_index], training_labels[test_index]
            if verbose:
                print(f"Calculating with fold {i}")
            clf.fit(train_data, train_labels)
            predictions = clf.predict(val_data)
            val_acc, val_mcc = print_metrics(predictions, val_labels, verbose=verbose)
            if verbose:
                plot_confusion(predictions, test_labels)
            MCCs_val.append(val_mcc)
            accs_val.append(val_acc)
        clf.fit(training_set, training_labels)
        predictions = clf.predict(testing_set)
        test_acc, test_mcc = print_metrics(predictions, testing_labels, verbose=verbose)
        accs_test.append(test_acc)
        MCCs_test.append(test_mcc)
    return MCCs_val, MCCs_test, accs_val, accs_test

def plot_results_CV(MCCs_val, MCCs_test, accs_val, accs_test, y_lims=None):
    MCCs_val = np.array(MCCs_val)
    MCCs_val[np.isnan(MCCs_val)] = 0
    MCCs_test = np.array(MCCs_test)
    MCCs_test[np.isnan(MCCs_test)] = 0
    fig, ax = plt.subplots(1,2, figsize=(14,6))

    ax[0].boxplot([np.array(accs_val)[~np.isnan(accs_val)], np.array(accs_test)[~np.isnan(accs_test)]], labels=["Validation", "Testing"])
    ax[1].boxplot([MCCs_val, MCCs_test], labels=["Validation", "Testing"])
    if y_lims is not None:
        ax[0].set_ylim(top=y_lims[1], bottom=y_lims[0])
        ax[1].set_ylim(top=y_lims[1], bottom=y_lims[0])
    else:
        y_min = -0.1+np.nanmin([np.nanmin(accs_val), np.nanmin(accs_test), np.nanmin(MCCs_val), np.nanmin(MCCs_test)])
        y_max = 0.1+np.nanmax([np.nanmax(accs_val), np.nanmax(accs_test), np.nanmax(MCCs_val), np.nanmax(MCCs_test)])
        ax[0].set_ylim(top=y_max, bottom=y_min)
        ax[1].set_ylim(top=y_max, bottom=y_min)
    ax[0].set_ylabel("Accuracy")
    ax[1].set_ylabel("MCC")

# %%
C= 4.17531
gamm = 0.02807
svm = SVC(C=C, kernel="rbf", gamma=gamm, class_weight="balanced")
MCC_val_svm, MCC_test_svm, acc_val_svm, acc_test_svm = run_cross_validation(joined_features, active, folds=10, verbose=False, clf=svm)

# %%
plot_results_CV(MCC_val_svm, MCC_test_svm, acc_val_svm, acc_test_svm, y_lims=(0, 1))

# %%
model = DecisionTreeClassifier(random_state=42)
MCC_val_tree, MCC_test_tree, acc_val_tree, acc_test_tree = run_cross_validation(joined_features, active, folds=10, verbose=False, clf=model)

# %%
plot_results_CV(MCC_val_tree, MCC_test_tree, acc_val_tree, acc_test_tree, y_lims=(0, 1))

# %%
MCC_train_RF, MCC_test_RF, acc_train_RF, acc_test_RF = run_cross_validation(joined_features, active, folds=10, verbose=False)

# %%
plot_results_CV(MCC_train_RF, MCC_test_RF, acc_train_RF, acc_test_RF, y_lims=(0, 1))

# %%
percentiles = list(range(1,101,5))
n_features = []
MCCs = []
accs = []
skf = StratifiedKFold(n_splits=10)
for percentile in percentiles:
    feat_select = SelectPercentile(chi2, percentile=percentile)
    transform_features = feat_select.fit_transform(joined_features, active)
    n_features.append(transform_features.shape[1])
    mcc_CV = []
    acc_CV = []
    for i, (train_index, test_index) in enumerate(skf.split(transform_features, active)):
        train_data, test_data = transform_features[train_index], transform_features[test_index]
        train_labels, test_labels = active[train_index], active[test_index]
        print(f"Calculating with fold {i}, percentile {percentile}")
        clf = RandomForestClassifier(random_state=42)
        clf.fit(train_data, train_labels)
        predictions = clf.predict(test_data)
        test_acc, test_mcc = print_metrics(predictions, test_labels)
        mcc_CV.append(test_mcc)
        acc_CV.append(test_acc)
    MCCs.append(mcc_CV)
    accs.append(acc_CV)
# Out:
# Calculating with fold 0, percentile 1
# NER: 0.406, Sensitivity or recall: 0.581, Specificity: 0.231, Precision: 0.474, Correctly classified: 0.421, MCC: -0.199
# Calculating with fold 1, percentile 1
# NER: 0.547, Sensitivity or recall: 0.710, Specificity: 0.385, Precision: 0.579, Correctly classified: 0.561, MCC: 0.100
# Calculating with fold 2, percentile 1
# NER: 0.782, Sensitivity or recall: 0.871, Specificity: 0.692, Precision: 0.771, Correctly classified: 0.789, MCC: 0.576
# Calculating with fold 3, percentile 1
# NER: 0.503, Sensitivity or recall: 0.645, Specificity: 0.360, Precision: 0.556, Correctly classified: 0.518, MCC: 0.005
# Calculating with fold 4, percentile 1
# NER: 0.764, Sensitivity or recall: 0.968, Specificity: 0.560, Precision: 0.732, Correctly classified: 0.786, MCC: 0.592
# Calculating with fold 5, percentile 1
# NER: 0.808, Sensitivity or recall: 0.935, Specificity: 0.680, Precision: 0.784, Correctly classified: 0.821, MCC: 0.646
# Calculating with fold 6, percentile 1
# NER: 0.920, Sensitivity or recall: 1.000, Specificity: 0.840, Precision: 0.886, Correctly classified: 0.929, MCC: 0.863
# Calculating with fold 7, percentile 1
# NER: 0.892, Sensitivity or recall: 0.903, Specificity: 0.880, Precision: 0.903, Correctly classified: 0.893, MCC: 0.783
# Calculating with fold 8, percentile 1
# NER: 0.751, Sensitivity or recall: 0.742, Specificity: 0.760, Precision: 0.793, Correctly classified: 0.750, MCC: 0.499
# Calculating with fold 9, percentile 1
# NER: 0.855, Sensitivity or recall: 0.710, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.839, MCC: 0.722
# Calculating with fold 0, percentile 6
# NER: 0.525, Sensitivity or recall: 0.742, Specificity: 0.308, Precision: 0.561, Correctly classified: 0.544, MCC: 0.055
# Calculating with fold 1, percentile 6
# NER: 0.579, Sensitivity or recall: 0.774, Specificity: 0.385, Precision: 0.600, Correctly classified: 0.596, MCC: 0.173
# Calculating with fold 2, percentile 6
# NER: 0.692, Sensitivity or recall: 0.806, Specificity: 0.577, Precision: 0.694, Correctly classified: 0.702, MCC: 0.396
# Calculating with fold 3, percentile 6
# NER: 0.559, Sensitivity or recall: 0.677, Specificity: 0.440, Precision: 0.600, Correctly classified: 0.571, MCC: 0.121
# Calculating with fold 4, percentile 6
# NER: 0.739, Sensitivity or recall: 0.839, Specificity: 0.640, Precision: 0.743, Correctly classified: 0.750, MCC: 0.492
# Calculating with fold 5, percentile 6
# NER: 0.735, Sensitivity or recall: 0.871, Specificity: 0.600, Precision: 0.730, Correctly classified: 0.750, MCC: 0.494
# Calculating with fold 6, percentile 6
# NER: 0.872, Sensitivity or recall: 0.903, Specificity: 0.840, Precision: 0.875, Correctly classified: 0.875, MCC: 0.747
# Calculating with fold 7, percentile 6
# NER: 0.912, Sensitivity or recall: 0.903, Specificity: 0.920, Precision: 0.933, Correctly classified: 0.911, MCC: 0.821
# Calculating with fold 8, percentile 6
# NER: 0.763, Sensitivity or recall: 0.645, Specificity: 0.880, Precision: 0.870, Correctly classified: 0.750, MCC: 0.531
# Calculating with fold 9, percentile 6
# NER: 0.823, Sensitivity or recall: 0.645, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.804, MCC: 0.669
# Calculating with fold 0, percentile 11
# NER: 0.489, Sensitivity or recall: 0.710, Specificity: 0.269, Precision: 0.537, Correctly classified: 0.509, MCC: -0.023
# Calculating with fold 1, percentile 11
# NER: 0.541, Sensitivity or recall: 0.774, Specificity: 0.308, Precision: 0.571, Correctly classified: 0.561, MCC: 0.093
# Calculating with fold 2, percentile 11
# NER: 0.676, Sensitivity or recall: 0.774, Specificity: 0.577, Precision: 0.686, Correctly classified: 0.684, MCC: 0.359
# Calculating with fold 3, percentile 11
# NER: 0.555, Sensitivity or recall: 0.710, Specificity: 0.400, Precision: 0.595, Correctly classified: 0.571, MCC: 0.115
# Calculating with fold 4, percentile 11
# NER: 0.800, Sensitivity or recall: 1.000, Specificity: 0.600, Precision: 0.756, Correctly classified: 0.821, MCC: 0.674
# Calculating with fold 5, percentile 11
# NER: 0.820, Sensitivity or recall: 1.000, Specificity: 0.640, Precision: 0.775, Correctly classified: 0.839, MCC: 0.704
# Calculating with fold 6, percentile 11
# NER: 0.852, Sensitivity or recall: 0.903, Specificity: 0.800, Precision: 0.848, Correctly classified: 0.857, MCC: 0.711
# Calculating with fold 7, percentile 11
# NER: 0.799, Sensitivity or recall: 0.839, Specificity: 0.760, Precision: 0.812, Correctly classified: 0.804, MCC: 0.601
# Calculating with fold 8, percentile 11
# NER: 0.723, Sensitivity or recall: 0.645, Specificity: 0.800, Precision: 0.800, Correctly classified: 0.714, MCC: 0.445
# Calculating with fold 9, percentile 11
# NER: 0.823, Sensitivity or recall: 0.645, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.804, MCC: 0.669
# Calculating with fold 0, percentile 16
# NER: 0.525, Sensitivity or recall: 0.742, Specificity: 0.308, Precision: 0.561, Correctly classified: 0.544, MCC: 0.055
# Calculating with fold 1, percentile 16
# NER: 0.634, Sensitivity or recall: 0.806, Specificity: 0.462, Precision: 0.641, Correctly classified: 0.649, MCC: 0.287
# Calculating with fold 2, percentile 16
# NER: 0.749, Sensitivity or recall: 0.806, Specificity: 0.692, Precision: 0.758, Correctly classified: 0.754, MCC: 0.503
# Calculating with fold 3, percentile 16
# NER: 0.591, Sensitivity or recall: 0.742, Specificity: 0.440, Precision: 0.622, Correctly classified: 0.607, MCC: 0.191
# Calculating with fold 4, percentile 16
# NER: 0.732, Sensitivity or recall: 0.903, Specificity: 0.560, Precision: 0.718, Correctly classified: 0.750, MCC: 0.501
# Calculating with fold 5, percentile 16
# NER: 0.748, Sensitivity or recall: 0.935, Specificity: 0.560, Precision: 0.725, Correctly classified: 0.768, MCC: 0.545
# Calculating with fold 6, percentile 16
# NER: 0.888, Sensitivity or recall: 0.935, Specificity: 0.840, Precision: 0.879, Correctly classified: 0.893, MCC: 0.784
# Calculating with fold 7, percentile 16
# NER: 0.803, Sensitivity or recall: 0.806, Specificity: 0.800, Precision: 0.833, Correctly classified: 0.804, MCC: 0.605
# Calculating with fold 8, percentile 16
# NER: 0.710, Sensitivity or recall: 0.581, Specificity: 0.840, Precision: 0.818, Correctly classified: 0.696, MCC: 0.428
# Calculating with fold 9, percentile 16
# NER: 0.823, Sensitivity or recall: 0.645, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.804, MCC: 0.669
# Calculating with fold 0, percentile 21
# NER: 0.496, Sensitivity or recall: 0.645, Specificity: 0.346, Precision: 0.541, Correctly classified: 0.509, MCC: -0.009
# Calculating with fold 1, percentile 21
# NER: 0.557, Sensitivity or recall: 0.806, Specificity: 0.308, Precision: 0.581, Correctly classified: 0.579, MCC: 0.132
# Calculating with fold 2, percentile 21
# NER: 0.624, Sensitivity or recall: 0.710, Specificity: 0.538, Precision: 0.647, Correctly classified: 0.632, MCC: 0.252
# Calculating with fold 3, percentile 21
# NER: 0.615, Sensitivity or recall: 0.710, Specificity: 0.520, Precision: 0.647, Correctly classified: 0.625, MCC: 0.234
# Calculating with fold 4, percentile 21
# NER: 0.719, Sensitivity or recall: 0.839, Specificity: 0.600, Precision: 0.722, Correctly classified: 0.732, MCC: 0.455
# Calculating with fold 5, percentile 21
# NER: 0.788, Sensitivity or recall: 0.935, Specificity: 0.640, Precision: 0.763, Correctly classified: 0.804, MCC: 0.613
# Calculating with fold 6, percentile 21
# NER: 0.872, Sensitivity or recall: 0.903, Specificity: 0.840, Precision: 0.875, Correctly classified: 0.875, MCC: 0.747
# Calculating with fold 7, percentile 21
# NER: 0.799, Sensitivity or recall: 0.839, Specificity: 0.760, Precision: 0.812, Correctly classified: 0.804, MCC: 0.601
# Calculating with fold 8, percentile 21
# NER: 0.763, Sensitivity or recall: 0.645, Specificity: 0.880, Precision: 0.870, Correctly classified: 0.750, MCC: 0.531
# Calculating with fold 9, percentile 21
# NER: 0.806, Sensitivity or recall: 0.613, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.786, MCC: 0.644
# Calculating with fold 0, percentile 26
# NER: 0.438, Sensitivity or recall: 0.645, Specificity: 0.231, Precision: 0.500, Correctly classified: 0.456, MCC: -0.135
# Calculating with fold 1, percentile 26
# NER: 0.625, Sensitivity or recall: 0.903, Specificity: 0.346, Precision: 0.622, Correctly classified: 0.649, MCC: 0.305
# Calculating with fold 2, percentile 26
# NER: 0.589, Sensitivity or recall: 0.677, Specificity: 0.500, Precision: 0.618, Correctly classified: 0.596, MCC: 0.180
# Calculating with fold 3, percentile 26
# NER: 0.627, Sensitivity or recall: 0.774, Specificity: 0.480, Precision: 0.649, Correctly classified: 0.643, MCC: 0.267
# Calculating with fold 4, percentile 26
# NER: 0.759, Sensitivity or recall: 0.839, Specificity: 0.680, Precision: 0.765, Correctly classified: 0.768, MCC: 0.528
# Calculating with fold 5, percentile 26
# NER: 0.772, Sensitivity or recall: 0.903, Specificity: 0.640, Precision: 0.757, Correctly classified: 0.786, MCC: 0.570
# Calculating with fold 6, percentile 26
# NER: 0.875, Sensitivity or recall: 0.871, Specificity: 0.880, Precision: 0.900, Correctly classified: 0.875, MCC: 0.749
# Calculating with fold 7, percentile 26
# NER: 0.803, Sensitivity or recall: 0.806, Specificity: 0.800, Precision: 0.833, Correctly classified: 0.804, MCC: 0.605
# Calculating with fold 8, percentile 26
# NER: 0.759, Sensitivity or recall: 0.677, Specificity: 0.840, Precision: 0.840, Correctly classified: 0.750, MCC: 0.517
# Calculating with fold 9, percentile 26
# NER: 0.806, Sensitivity or recall: 0.613, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.786, MCC: 0.644
# Calculating with fold 0, percentile 31
# NER: 0.435, Sensitivity or recall: 0.677, Specificity: 0.192, Precision: 0.500, Correctly classified: 0.456, MCC: -0.147
# Calculating with fold 1, percentile 31
# NER: 0.573, Sensitivity or recall: 0.839, Specificity: 0.308, Precision: 0.591, Correctly classified: 0.596, MCC: 0.174
# Calculating with fold 2, percentile 31
# NER: 0.643, Sensitivity or recall: 0.710, Specificity: 0.577, Precision: 0.667, Correctly classified: 0.649, MCC: 0.289
# Calculating with fold 3, percentile 31
# NER: 0.672, Sensitivity or recall: 0.903, Specificity: 0.440, Precision: 0.667, Correctly classified: 0.696, MCC: 0.394
# Calculating with fold 4, percentile 31
# NER: 0.775, Sensitivity or recall: 0.871, Specificity: 0.680, Precision: 0.771, Correctly classified: 0.786, MCC: 0.566
# Calculating with fold 5, percentile 31
# NER: 0.768, Sensitivity or recall: 0.935, Specificity: 0.600, Precision: 0.744, Correctly classified: 0.786, MCC: 0.579
# Calculating with fold 6, percentile 31
# NER: 0.872, Sensitivity or recall: 0.903, Specificity: 0.840, Precision: 0.875, Correctly classified: 0.875, MCC: 0.747
# Calculating with fold 7, percentile 31
# NER: 0.799, Sensitivity or recall: 0.839, Specificity: 0.760, Precision: 0.812, Correctly classified: 0.804, MCC: 0.601
# Calculating with fold 8, percentile 31
# NER: 0.759, Sensitivity or recall: 0.677, Specificity: 0.840, Precision: 0.840, Correctly classified: 0.750, MCC: 0.517
# Calculating with fold 9, percentile 31
# NER: 0.790, Sensitivity or recall: 0.581, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.768, MCC: 0.618
# Calculating with fold 0, percentile 36
# NER: 0.493, Sensitivity or recall: 0.677, Specificity: 0.308, Precision: 0.538, Correctly classified: 0.509, MCC: -0.016
# Calculating with fold 1, percentile 36
# NER: 0.666, Sensitivity or recall: 0.871, Specificity: 0.462, Precision: 0.659, Correctly classified: 0.684, MCC: 0.369
# Calculating with fold 2, percentile 36
# NER: 0.646, Sensitivity or recall: 0.677, Specificity: 0.615, Precision: 0.677, Correctly classified: 0.649, MCC: 0.293
# Calculating with fold 3, percentile 36
# NER: 0.563, Sensitivity or recall: 0.645, Specificity: 0.480, Precision: 0.606, Correctly classified: 0.571, MCC: 0.126
# Calculating with fold 4, percentile 36
# NER: 0.743, Sensitivity or recall: 0.806, Specificity: 0.680, Precision: 0.758, Correctly classified: 0.750, MCC: 0.492
# Calculating with fold 5, percentile 36
# NER: 0.768, Sensitivity or recall: 0.935, Specificity: 0.600, Precision: 0.744, Correctly classified: 0.786, MCC: 0.579
# Calculating with fold 6, percentile 36
# NER: 0.872, Sensitivity or recall: 0.903, Specificity: 0.840, Precision: 0.875, Correctly classified: 0.875, MCC: 0.747
# Calculating with fold 7, percentile 36
# NER: 0.835, Sensitivity or recall: 0.871, Specificity: 0.800, Precision: 0.844, Correctly classified: 0.839, MCC: 0.674
# Calculating with fold 8, percentile 36
# NER: 0.706, Sensitivity or recall: 0.613, Specificity: 0.800, Precision: 0.792, Correctly classified: 0.696, MCC: 0.415
# Calculating with fold 9, percentile 36
# NER: 0.806, Sensitivity or recall: 0.613, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.786, MCC: 0.644
# Calculating with fold 0, percentile 41
# NER: 0.435, Sensitivity or recall: 0.677, Specificity: 0.192, Precision: 0.500, Correctly classified: 0.456, MCC: -0.147
# Calculating with fold 1, percentile 41
# NER: 0.557, Sensitivity or recall: 0.806, Specificity: 0.308, Precision: 0.581, Correctly classified: 0.579, MCC: 0.132
# Calculating with fold 2, percentile 41
# NER: 0.624, Sensitivity or recall: 0.710, Specificity: 0.538, Precision: 0.647, Correctly classified: 0.632, MCC: 0.252
# Calculating with fold 3, percentile 41
# NER: 0.591, Sensitivity or recall: 0.742, Specificity: 0.440, Precision: 0.622, Correctly classified: 0.607, MCC: 0.191
# Calculating with fold 4, percentile 41
# NER: 0.755, Sensitivity or recall: 0.871, Specificity: 0.640, Precision: 0.750, Correctly classified: 0.768, MCC: 0.530
# Calculating with fold 5, percentile 41
# NER: 0.768, Sensitivity or recall: 0.935, Specificity: 0.600, Precision: 0.744, Correctly classified: 0.786, MCC: 0.579
# Calculating with fold 6, percentile 41
# NER: 0.888, Sensitivity or recall: 0.935, Specificity: 0.840, Precision: 0.879, Correctly classified: 0.893, MCC: 0.784
# Calculating with fold 7, percentile 41
# NER: 0.803, Sensitivity or recall: 0.806, Specificity: 0.800, Precision: 0.833, Correctly classified: 0.804, MCC: 0.605
# Calculating with fold 8, percentile 41
# NER: 0.723, Sensitivity or recall: 0.645, Specificity: 0.800, Precision: 0.800, Correctly classified: 0.714, MCC: 0.445
# Calculating with fold 9, percentile 41
# NER: 0.806, Sensitivity or recall: 0.613, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.786, MCC: 0.644
# Calculating with fold 0, percentile 46
# NER: 0.502, Sensitivity or recall: 0.774, Specificity: 0.231, Precision: 0.545, Correctly classified: 0.526, MCC: 0.006
# Calculating with fold 1, percentile 46
# NER: 0.609, Sensitivity or recall: 0.871, Specificity: 0.346, Precision: 0.614, Correctly classified: 0.632, MCC: 0.258
# Calculating with fold 2, percentile 46
# NER: 0.676, Sensitivity or recall: 0.774, Specificity: 0.577, Precision: 0.686, Correctly classified: 0.684, MCC: 0.359
# Calculating with fold 3, percentile 46
# NER: 0.627, Sensitivity or recall: 0.774, Specificity: 0.480, Precision: 0.649, Correctly classified: 0.643, MCC: 0.267
# Calculating with fold 4, percentile 46
# NER: 0.703, Sensitivity or recall: 0.806, Specificity: 0.600, Precision: 0.714, Correctly classified: 0.714, MCC: 0.417
# Calculating with fold 5, percentile 46
# NER: 0.748, Sensitivity or recall: 0.935, Specificity: 0.560, Precision: 0.725, Correctly classified: 0.768, MCC: 0.545
# Calculating with fold 6, percentile 46
# NER: 0.868, Sensitivity or recall: 0.935, Specificity: 0.800, Precision: 0.853, Correctly classified: 0.875, MCC: 0.749
# Calculating with fold 7, percentile 46
# NER: 0.787, Sensitivity or recall: 0.774, Specificity: 0.800, Precision: 0.828, Correctly classified: 0.786, MCC: 0.571
# Calculating with fold 8, percentile 46
# NER: 0.743, Sensitivity or recall: 0.645, Specificity: 0.840, Precision: 0.833, Correctly classified: 0.732, MCC: 0.487
# Calculating with fold 9, percentile 46
# NER: 0.790, Sensitivity or recall: 0.581, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.768, MCC: 0.618
# Calculating with fold 0, percentile 51
# NER: 0.467, Sensitivity or recall: 0.742, Specificity: 0.192, Precision: 0.523, Correctly classified: 0.491, MCC: -0.078
# Calculating with fold 1, percentile 51
# NER: 0.615, Sensitivity or recall: 0.806, Specificity: 0.423, Precision: 0.625, Correctly classified: 0.632, MCC: 0.250
# Calculating with fold 2, percentile 51
# NER: 0.573, Sensitivity or recall: 0.645, Specificity: 0.500, Precision: 0.606, Correctly classified: 0.579, MCC: 0.146
# Calculating with fold 3, percentile 51
# NER: 0.643, Sensitivity or recall: 0.806, Specificity: 0.480, Precision: 0.658, Correctly classified: 0.661, MCC: 0.305
# Calculating with fold 4, percentile 51
# NER: 0.743, Sensitivity or recall: 0.806, Specificity: 0.680, Precision: 0.758, Correctly classified: 0.750, MCC: 0.492
# Calculating with fold 5, percentile 51
# NER: 0.808, Sensitivity or recall: 0.935, Specificity: 0.680, Precision: 0.784, Correctly classified: 0.821, MCC: 0.646
# Calculating with fold 6, percentile 51
# NER: 0.852, Sensitivity or recall: 0.903, Specificity: 0.800, Precision: 0.848, Correctly classified: 0.857, MCC: 0.711
# Calculating with fold 7, percentile 51
# NER: 0.783, Sensitivity or recall: 0.806, Specificity: 0.760, Precision: 0.806, Correctly classified: 0.786, MCC: 0.566
# Calculating with fold 8, percentile 51
# NER: 0.763, Sensitivity or recall: 0.645, Specificity: 0.880, Precision: 0.870, Correctly classified: 0.750, MCC: 0.531
# Calculating with fold 9, percentile 51
# NER: 0.823, Sensitivity or recall: 0.645, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.804, MCC: 0.669
# Calculating with fold 0, percentile 56
# NER: 0.473, Sensitivity or recall: 0.677, Specificity: 0.269, Precision: 0.525, Correctly classified: 0.491, MCC: -0.058
# Calculating with fold 1, percentile 56
# NER: 0.631, Sensitivity or recall: 0.839, Specificity: 0.423, Precision: 0.634, Correctly classified: 0.649, MCC: 0.290
# Calculating with fold 2, percentile 56
# NER: 0.627, Sensitivity or recall: 0.677, Specificity: 0.577, Precision: 0.656, Correctly classified: 0.632, MCC: 0.255
# Calculating with fold 3, percentile 56
# NER: 0.623, Sensitivity or recall: 0.806, Specificity: 0.440, Precision: 0.641, Correctly classified: 0.643, MCC: 0.266
# Calculating with fold 4, percentile 56
# NER: 0.723, Sensitivity or recall: 0.806, Specificity: 0.640, Precision: 0.735, Correctly classified: 0.732, MCC: 0.454
# Calculating with fold 5, percentile 56
# NER: 0.768, Sensitivity or recall: 0.935, Specificity: 0.600, Precision: 0.744, Correctly classified: 0.786, MCC: 0.579
# Calculating with fold 6, percentile 56
# NER: 0.888, Sensitivity or recall: 0.935, Specificity: 0.840, Precision: 0.879, Correctly classified: 0.893, MCC: 0.784
# Calculating with fold 7, percentile 56
# NER: 0.787, Sensitivity or recall: 0.774, Specificity: 0.800, Precision: 0.828, Correctly classified: 0.786, MCC: 0.571
# Calculating with fold 8, percentile 56
# NER: 0.698, Sensitivity or recall: 0.516, Specificity: 0.880, Precision: 0.842, Correctly classified: 0.679, MCC: 0.416
# Calculating with fold 9, percentile 56
# NER: 0.790, Sensitivity or recall: 0.581, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.768, MCC: 0.618
# Calculating with fold 0, percentile 61
# NER: 0.467, Sensitivity or recall: 0.742, Specificity: 0.192, Precision: 0.523, Correctly classified: 0.491, MCC: -0.078
# Calculating with fold 1, percentile 61
# NER: 0.512, Sensitivity or recall: 0.677, Specificity: 0.346, Precision: 0.553, Correctly classified: 0.526, MCC: 0.025
# Calculating with fold 2, percentile 61
# NER: 0.695, Sensitivity or recall: 0.774, Specificity: 0.615, Precision: 0.706, Correctly classified: 0.702, MCC: 0.396
# Calculating with fold 3, percentile 61
# NER: 0.595, Sensitivity or recall: 0.710, Specificity: 0.480, Precision: 0.629, Correctly classified: 0.607, MCC: 0.195
# Calculating with fold 4, percentile 61
# NER: 0.739, Sensitivity or recall: 0.839, Specificity: 0.640, Precision: 0.743, Correctly classified: 0.750, MCC: 0.492
# Calculating with fold 5, percentile 61
# NER: 0.748, Sensitivity or recall: 0.935, Specificity: 0.560, Precision: 0.725, Correctly classified: 0.768, MCC: 0.545
# Calculating with fold 6, percentile 61
# NER: 0.868, Sensitivity or recall: 0.935, Specificity: 0.800, Precision: 0.853, Correctly classified: 0.875, MCC: 0.749
# Calculating with fold 7, percentile 61
# NER: 0.783, Sensitivity or recall: 0.806, Specificity: 0.760, Precision: 0.806, Correctly classified: 0.786, MCC: 0.566
# Calculating with fold 8, percentile 61
# NER: 0.759, Sensitivity or recall: 0.677, Specificity: 0.840, Precision: 0.840, Correctly classified: 0.750, MCC: 0.517
# Calculating with fold 9, percentile 61
# NER: 0.774, Sensitivity or recall: 0.548, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.750, MCC: 0.593
# Calculating with fold 0, percentile 66
# NER: 0.506, Sensitivity or recall: 0.742, Specificity: 0.269, Precision: 0.548, Correctly classified: 0.526, MCC: 0.013
# Calculating with fold 1, percentile 66
# NER: 0.628, Sensitivity or recall: 0.871, Specificity: 0.385, Precision: 0.628, Correctly classified: 0.649, MCC: 0.296
# Calculating with fold 2, percentile 66
# NER: 0.695, Sensitivity or recall: 0.774, Specificity: 0.615, Precision: 0.706, Correctly classified: 0.702, MCC: 0.396
# Calculating with fold 3, percentile 66
# NER: 0.623, Sensitivity or recall: 0.806, Specificity: 0.440, Precision: 0.641, Correctly classified: 0.643, MCC: 0.266
# Calculating with fold 4, percentile 66
# NER: 0.723, Sensitivity or recall: 0.806, Specificity: 0.640, Precision: 0.735, Correctly classified: 0.732, MCC: 0.454
# Calculating with fold 5, percentile 66
# NER: 0.768, Sensitivity or recall: 0.935, Specificity: 0.600, Precision: 0.744, Correctly classified: 0.786, MCC: 0.579
# Calculating with fold 6, percentile 66
# NER: 0.904, Sensitivity or recall: 0.968, Specificity: 0.840, Precision: 0.882, Correctly classified: 0.911, MCC: 0.822
# Calculating with fold 7, percentile 66
# NER: 0.839, Sensitivity or recall: 0.839, Specificity: 0.840, Precision: 0.867, Correctly classified: 0.839, MCC: 0.677
# Calculating with fold 8, percentile 66
# NER: 0.743, Sensitivity or recall: 0.645, Specificity: 0.840, Precision: 0.833, Correctly classified: 0.732, MCC: 0.487
# Calculating with fold 9, percentile 66
# NER: 0.806, Sensitivity or recall: 0.613, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.786, MCC: 0.644
# Calculating with fold 0, percentile 71
# NER: 0.489, Sensitivity or recall: 0.710, Specificity: 0.269, Precision: 0.537, Correctly classified: 0.509, MCC: -0.023
# Calculating with fold 1, percentile 71
# NER: 0.596, Sensitivity or recall: 0.806, Specificity: 0.385, Precision: 0.610, Correctly classified: 0.614, MCC: 0.212
# Calculating with fold 2, percentile 71
# NER: 0.614, Sensitivity or recall: 0.613, Specificity: 0.615, Precision: 0.655, Correctly classified: 0.614, MCC: 0.227
# Calculating with fold 3, percentile 71
# NER: 0.555, Sensitivity or recall: 0.710, Specificity: 0.400, Precision: 0.595, Correctly classified: 0.571, MCC: 0.115
# Calculating with fold 4, percentile 71
# NER: 0.743, Sensitivity or recall: 0.806, Specificity: 0.680, Precision: 0.758, Correctly classified: 0.750, MCC: 0.492
# Calculating with fold 5, percentile 71
# NER: 0.748, Sensitivity or recall: 0.935, Specificity: 0.560, Precision: 0.725, Correctly classified: 0.768, MCC: 0.545
# Calculating with fold 6, percentile 71
# NER: 0.828, Sensitivity or recall: 0.935, Specificity: 0.720, Precision: 0.806, Correctly classified: 0.839, MCC: 0.680
# Calculating with fold 7, percentile 71
# NER: 0.835, Sensitivity or recall: 0.871, Specificity: 0.800, Precision: 0.844, Correctly classified: 0.839, MCC: 0.674
# Calculating with fold 8, percentile 71
# NER: 0.743, Sensitivity or recall: 0.645, Specificity: 0.840, Precision: 0.833, Correctly classified: 0.732, MCC: 0.487
# Calculating with fold 9, percentile 71
# NER: 0.823, Sensitivity or recall: 0.645, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.804, MCC: 0.669
# Calculating with fold 0, percentile 76
# NER: 0.489, Sensitivity or recall: 0.710, Specificity: 0.269, Precision: 0.537, Correctly classified: 0.509, MCC: -0.023
# Calculating with fold 1, percentile 76
# NER: 0.489, Sensitivity or recall: 0.710, Specificity: 0.269, Precision: 0.537, Correctly classified: 0.509, MCC: -0.023
# Calculating with fold 2, percentile 76
# NER: 0.614, Sensitivity or recall: 0.613, Specificity: 0.615, Precision: 0.655, Correctly classified: 0.614, MCC: 0.227
# Calculating with fold 3, percentile 76
# NER: 0.555, Sensitivity or recall: 0.710, Specificity: 0.400, Precision: 0.595, Correctly classified: 0.571, MCC: 0.115
# Calculating with fold 4, percentile 76
# NER: 0.779, Sensitivity or recall: 0.839, Specificity: 0.720, Precision: 0.788, Correctly classified: 0.786, MCC: 0.565
# Calculating with fold 5, percentile 76
# NER: 0.768, Sensitivity or recall: 0.935, Specificity: 0.600, Precision: 0.744, Correctly classified: 0.786, MCC: 0.579
# Calculating with fold 6, percentile 76
# NER: 0.888, Sensitivity or recall: 0.935, Specificity: 0.840, Precision: 0.879, Correctly classified: 0.893, MCC: 0.784
# Calculating with fold 7, percentile 76
# NER: 0.835, Sensitivity or recall: 0.871, Specificity: 0.800, Precision: 0.844, Correctly classified: 0.839, MCC: 0.674
# Calculating with fold 8, percentile 76
# NER: 0.766, Sensitivity or recall: 0.613, Specificity: 0.920, Precision: 0.905, Correctly classified: 0.750, MCC: 0.547
# Calculating with fold 9, percentile 76
# NER: 0.806, Sensitivity or recall: 0.613, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.786, MCC: 0.644
# Calculating with fold 0, percentile 81
# NER: 0.502, Sensitivity or recall: 0.774, Specificity: 0.231, Precision: 0.545, Correctly classified: 0.526, MCC: 0.006
# Calculating with fold 1, percentile 81
# NER: 0.560, Sensitivity or recall: 0.774, Specificity: 0.346, Precision: 0.585, Correctly classified: 0.579, MCC: 0.133
# Calculating with fold 2, percentile 81
# NER: 0.630, Sensitivity or recall: 0.645, Specificity: 0.615, Precision: 0.667, Correctly classified: 0.632, MCC: 0.260
# Calculating with fold 3, percentile 81
# NER: 0.595, Sensitivity or recall: 0.710, Specificity: 0.480, Precision: 0.629, Correctly classified: 0.607, MCC: 0.195
# Calculating with fold 4, percentile 81
# NER: 0.683, Sensitivity or recall: 0.806, Specificity: 0.560, Precision: 0.694, Correctly classified: 0.696, MCC: 0.380
# Calculating with fold 5, percentile 81
# NER: 0.800, Sensitivity or recall: 1.000, Specificity: 0.600, Precision: 0.756, Correctly classified: 0.821, MCC: 0.674
# Calculating with fold 6, percentile 81
# NER: 0.868, Sensitivity or recall: 0.935, Specificity: 0.800, Precision: 0.853, Correctly classified: 0.875, MCC: 0.749
# Calculating with fold 7, percentile 81
# NER: 0.799, Sensitivity or recall: 0.839, Specificity: 0.760, Precision: 0.812, Correctly classified: 0.804, MCC: 0.601
# Calculating with fold 8, percentile 81
# NER: 0.674, Sensitivity or recall: 0.548, Specificity: 0.800, Precision: 0.773, Correctly classified: 0.661, MCC: 0.355
# Calculating with fold 9, percentile 81
# NER: 0.806, Sensitivity or recall: 0.613, Specificity: 1.000, Precision: 1.000, Correctly classified: 0.786, MCC: 0.644
# Calculating with fold 0, percentile 86
# NER: 0.515, Sensitivity or recall: 0.645, Specificity: 0.385, Precision: 0.556, Correctly classified: 0.526, MCC: 0.031
# Calculating with fold 1, percentile 86
# NER: 0.615, Sensitivity or recall: 0.806, Specificity: 0.423, Precision: 0.625, Correctly classified: 0.632, MCC: 0.250
# Calculating with fold 2, percentile 86
# NER: 0.679, Sensitivity or recall: 0.742, Specificity: 0.615, Precision: 0.697, Correctly classified: 0.684, MCC: 0.360
# Calculating with fold 3, percentile 86
# NER: 0.607, Sensitivity or recall: 0.774, Specificity: 0.440, Precision: 0.632, Correctly classified: 0.625, MCC: 0.228
# Calculating with fold 4, percentile 86
# NER: 0.743, Sensitivity or recall: 0.806, Specificity: 0.680, Precision: 0.758, Correctly classified: 0.750, MCC: 0.492
# Calculating with fold 5, percentile 86
# NER: 0.788, Sensitivity or recall: 0.935, Specificity: 0.640, Precision: 0.763, Correctly classified: 0.804, MCC: 0.613
# Calculating with fold 6, percentile 86
# NER: 0.884, Sensitivity or recall: 0.968, Specificity: 0.800, Precision: 0.857, Correctly classified: 0.893, MCC: 0.788
# Calculating with fold 7, percentile 86
# NER: 0.835, Sensitivity or recall: 0.871, Specificity: 0.800, Precision: 0.844, Correctly classified: 0.839, MCC: 0.674
# Calculating with fold 8, percentile 86
# NER: 0.763, Sensitivity or recall: 0.645, Specificity: 0.880, Precision: 0.870, Correctly classified: 0.750, MCC: 0.531
# Calculating with fold 9, percentile 86
# NER: 0.786, Sensitivity or recall: 0.613, Specificity: 0.960, Precision: 0.950, Correctly classified: 0.768, MCC: 0.594
# Calculating with fold 0, percentile 91
# NER: 0.473, Sensitivity or recall: 0.677, Specificity: 0.269, Precision: 0.525, Correctly classified: 0.491, MCC: -0.058
# Calculating with fold 1, percentile 91
# NER: 0.563, Sensitivity or recall: 0.742, Specificity: 0.385, Precision: 0.590, Correctly classified: 0.579, MCC: 0.136
# Calculating with fold 2, percentile 91
# NER: 0.624, Sensitivity or recall: 0.710, Specificity: 0.538, Precision: 0.647, Correctly classified: 0.632, MCC: 0.252
# Calculating with fold 3, percentile 91
# NER: 0.587, Sensitivity or recall: 0.774, Specificity: 0.400, Precision: 0.615, Correctly classified: 0.607, MCC: 0.188
# Calculating with fold 4, percentile 91
# NER: 0.739, Sensitivity or recall: 0.839, Specificity: 0.640, Precision: 0.743, Correctly classified: 0.750, MCC: 0.492
# Calculating with fold 5, percentile 91
# NER: 0.768, Sensitivity or recall: 0.935, Specificity: 0.600, Precision: 0.744, Correctly classified: 0.786, MCC: 0.579
# Calculating with fold 6, percentile 91
# NER: 0.848, Sensitivity or recall: 0.935, Specificity: 0.760, Precision: 0.829, Correctly classified: 0.857, MCC: 0.714
# Calculating with fold 7, percentile 91
# NER: 0.803, Sensitivity or recall: 0.806, Specificity: 0.800, Precision: 0.833, Correctly classified: 0.804, MCC: 0.605
# Calculating with fold 8, percentile 91
# NER: 0.743, Sensitivity or recall: 0.645, Specificity: 0.840, Precision: 0.833, Correctly classified: 0.732, MCC: 0.487
# Calculating with fold 9, percentile 91
# NER: 0.786, Sensitivity or recall: 0.613, Specificity: 0.960, Precision: 0.950, Correctly classified: 0.768, MCC: 0.594
# Calculating with fold 0, percentile 96
# NER: 0.519, Sensitivity or recall: 0.806, Specificity: 0.231, Precision: 0.556, Correctly classified: 0.544, MCC: 0.045
# Calculating with fold 1, percentile 96
# NER: 0.618, Sensitivity or recall: 0.774, Specificity: 0.462, Precision: 0.632, Correctly classified: 0.632, MCC: 0.249
# Calculating with fold 2, percentile 96
# NER: 0.624, Sensitivity or recall: 0.710, Specificity: 0.538, Precision: 0.647, Correctly classified: 0.632, MCC: 0.252
# Calculating with fold 3, percentile 96
# NER: 0.591, Sensitivity or recall: 0.742, Specificity: 0.440, Precision: 0.622, Correctly classified: 0.607, MCC: 0.191
# Calculating with fold 4, percentile 96
# NER: 0.719, Sensitivity or recall: 0.839, Specificity: 0.600, Precision: 0.722, Correctly classified: 0.732, MCC: 0.455
# Calculating with fold 5, percentile 96
# NER: 0.768, Sensitivity or recall: 0.935, Specificity: 0.600, Precision: 0.744, Correctly classified: 0.786, MCC: 0.579
# Calculating with fold 6, percentile 96
# NER: 0.868, Sensitivity or recall: 0.935, Specificity: 0.800, Precision: 0.853, Correctly classified: 0.875, MCC: 0.749
# Calculating with fold 7, percentile 96
# NER: 0.783, Sensitivity or recall: 0.806, Specificity: 0.760, Precision: 0.806, Correctly classified: 0.786, MCC: 0.566
# Calculating with fold 8, percentile 96
# NER: 0.730, Sensitivity or recall: 0.581, Specificity: 0.880, Precision: 0.857, Correctly classified: 0.714, MCC: 0.473
# Calculating with fold 9, percentile 96
# NER: 0.786, Sensitivity or recall: 0.613, Specificity: 0.960, Precision: 0.950, Correctly classified: 0.768, MCC: 0.594

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(MCCs, labels=n_features)
plt.ylabel("MCC")
plt.xlabel("Features");

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(accs, labels=n_features)
plt.ylabel("Accuracy")
plt.xlabel("Features");

# %% [markdown]
# We use now cross validation with the SARS2 set only and then use SARS1 as test set, with a Random Forest

# %%
# features_full, features_GHDDI, active_SARS2, active_SARS1
MCC_val12, MCC_test12, acc_val12, acc_test12 = run_cross_validation(features_SARS2, active_SARS2, folds=5, verbose=False)
# Out:
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))

# %%
plot_results_CV(MCC_val12, MCC_test12, acc_val12, acc_test12)

# %% [markdown]
# And use CV with SARS1 to test with SARS 2

# %%
MCC_val12, MCC_test12, acc_val12, acc_test12 = run_cross_validation(features_GHDDI, active_SARS1, folds=10, verbose=False)

# %%
plot_results_CV(MCC_val12, MCC_test12, acc_val12, acc_test12)

# %% [markdown]
# We now keep only the features selected from the combination of mutual information, chi-squared and the most important features from a decision tree and random forest

# %%
best_features = joined_features[:, best]
best_features_SARS2 = features_SARS2[:, best]
best_features_SARS1 = features_GHDDI[:, best]
print(best_features.shape)
# Out:
# (563, 1)

# %%
model = RandomForestClassifier(random_state=42, class_weight="balanced")
MCC_val_all, MCC_test_all, acc_val_all, acc_test_all = run_cross_validation(best_features, active, clf=model, folds=10, verbose=False)

# %%
plot_results_CV(MCC_val_all, MCC_test_all, acc_val_all, acc_test_all)

# %%
model = RandomForestClassifier(random_state=42, n_estimators=1)
MCC_val_all, MCC_test_all, acc_val_all, acc_test_all = run_cross_validation(best_features, active, clf=model, folds=10, verbose=False)

# %%
plot_results_CV(MCC_val_all, MCC_test_all, acc_val_all, acc_test_all)

# %%
model = DecisionTreeClassifier(random_state=42)
MCC_val_all_tree, MCC_test_all_tree, acc_val_all_tree, acc_test_all_tree = run_cross_validation(best_features, active, clf=model, folds=10, verbose=False)

# %%
plot_results_CV(MCC_val_all_tree, MCC_test_all_tree, acc_val_all_tree, acc_test_all_tree)

# %% [markdown]
# Try with SVM

# %%
C= 4.17531
gamm = 0.02807
svm = SVC(C=C, kernel="rbf", gamma=gamm, class_weight="balanced")
MCC_val_svm, MCC_test_svm, acc_val_svm, acc_test_svm = run_cross_validation(best_features, active, folds=10, verbose=False, clf=svm)

# %%
plot_results_CV(MCC_val_svm, MCC_test_svm, acc_val_svm, acc_test_svm)

# %% [markdown]
# Use only SARS2 set

# %%
model = RandomForestClassifier(random_state=42, class_weight="balanced")
MCC_val_all, MCC_test_all, acc_val_all, acc_test_all = run_cross_validation(best_features_SARS2, active_SARS2, clf=model, folds=5, verbose=False)
# Out:
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:5: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp/(tp+fp)
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:5: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp/(tp+fp)
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))

# %%
plot_results_CV(MCC_val_all, MCC_test_all, acc_val_all, acc_test_all)

# %% [markdown]
# Use only SARS1 set

# %%
model = RandomForestClassifier(random_state=42, class_weight="balanced")
MCC_val_all, MCC_test_all, acc_val_all, acc_test_all = run_cross_validation(best_features_SARS1, active_SARS1, clf=model, folds=10, verbose=False)

# %%
plot_results_CV(MCC_val_all, MCC_test_all, acc_val_all, acc_test_all)

# %%
n_features = []
MCCs = []
accs = []
skf = StratifiedKFold(n_splits=10)
for n in range(1, len(best)):
    feat_select = SelectKBest(chi2, k=n)
    transform_features = feat_select.fit_transform(best_features, active)
    n_features.append(transform_features.shape[1])
    mcc_CV = []
    acc_CV = []
    for i, (train_index, test_index) in enumerate(skf.split(transform_features, active)):
        train_data, test_data = transform_features[train_index], transform_features[test_index]
        train_labels, test_labels = active[train_index], active[test_index]
        print(f"Calculating with fold {i}, percentile {percentile}")
        clf = DecisionTreeClassifier(random_state=42)
        clf.fit(train_data, train_labels)
        predictions = clf.predict(test_data)
        test_acc, test_mcc = print_metrics(predictions, test_labels)
        mcc_CV.append(test_mcc)
        acc_CV.append(test_acc)
    MCCs.append(mcc_CV)
    accs.append(acc_CV)

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(MCCs, labels=n_features)
plt.ylabel("MCC")
plt.xlabel("Features");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-ac949850a638> in <module>
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.boxplot(MCCs, labels=n_features)
#       3 plt.ylabel("MCC")
#       4 plt.xlabel("Features");
#
# ~/anaconda3/envs/drug_learning/lib/python3.8/site-packages/matplotlib/pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2435         whiskerprops=None, manage_ticks=True, autorange=False,
#    2436         zorder=None, *, data=None):
# -> 2437     return gca().boxplot(
#    2438         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2439         positions=positions, widths=widths, patch_artist=patch_artist,
#
# ~/anaconda3/envs/drug_learning/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     294                 f"for the old name will be dropped %(removal)s.")
#     295             kwargs[new] = kwargs.pop(old)
# --> 296         return func(*args, **kwargs)
#     297
#     298     # wrapper() must keep the same documented signature as func(): if we
#
# ~/anaconda3/envs/drug_learning/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/drug_learning/lib/python3.8/site-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3625             bootstrap = rcParams['boxplot.bootstrap']
#    3626
# -> 3627         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3628                                        labels=labels, autorange=autorange)
#    3629         if notch is None:
#
# ~/anaconda3/envs/drug_learning/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1169         labels = itertools.repeat(None)
#    1170     elif len(labels) != ncols:
# -> 1171         raise ValueError("Dimensions of labels and X must be compatible")
#    1172
#    1173     input_whis = whis
#
# ValueError: Dimensions of labels and X must be compatible

# %%
train_data, test_data, train_labels, test_labels = train_test_split(best_features, active, test_size=0.25, random_state=42, stratify=active)

# %%
grid_search_SVM(train_data, test_data, train_labels, test_labels)
# Out:
# C=0.01, gamma=0.001
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.0012689610031679222
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.0016102620275609393
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.0020433597178569417
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.002592943797404667
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.0032903445623126675
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.0041753189365604
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.005298316906283708
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.006723357536499335
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.008531678524172805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.010826367338740546
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.01373823795883263
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.017433288221999882
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.022122162910704492
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.02807216203941177
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.035622478902624426
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.04520353656360243
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.057361525104486784
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.0727895384398315
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.09236708571873861
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.11721022975334805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.14873521072935117
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.18873918221350977
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.2395026619987486
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.3039195382313198
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.38566204211634725
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# C=0.01, gamma=0.4893900918477494
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.6210169418915616
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=0.7880462815669912
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01, gamma=1.0
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.001
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.0012689610031679222
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.0016102620275609393
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.0020433597178569417
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.002592943797404667
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.0032903445623126675
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.0041753189365604
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.005298316906283708
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.006723357536499335
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.008531678524172805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.010826367338740546
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.01373823795883263
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.017433288221999882
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.022122162910704492
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.02807216203941177
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.035622478902624426
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.04520353656360243
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.057361525104486784
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.0727895384398315
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.09236708571873861
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.11721022975334805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.14873521072935117
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.18873918221350977
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.2395026619987486
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.3039195382313198
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.38566204211634725
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.4893900918477494
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.6210169418915616
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=0.7880462815669912
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.01373823795883263, gamma=1.0
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.018873918221350976, gamma=0.001
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.0012689610031679222
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.0016102620275609393
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.0020433597178569417
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.002592943797404667
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.0032903445623126675
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.0041753189365604
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.005298316906283708
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.006723357536499335
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.008531678524172805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.010826367338740546
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.01373823795883263
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.017433288221999882
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.022122162910704492
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.02807216203941177
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.035622478902624426
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.04520353656360243
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.057361525104486784
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.0727895384398315
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# C=0.018873918221350976, gamma=0.09236708571873861
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.11721022975334805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.14873521072935117
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.18873918221350977
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.2395026619987486
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.3039195382313198
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.38566204211634725
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.4893900918477494
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.018873918221350976, gamma=0.6210169418915616
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.018873918221350976, gamma=0.7880462815669912
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.018873918221350976, gamma=1.0
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.02592943797404667, gamma=0.001
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.0012689610031679222
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.0016102620275609393
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.0020433597178569417
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.002592943797404667
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.0032903445623126675
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.0041753189365604
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.005298316906283708
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.006723357536499335
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.008531678524172805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.010826367338740546
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.01373823795883263
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.017433288221999882
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.022122162910704492
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.02807216203941177
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.035622478902624426
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# C=0.02592943797404667, gamma=0.04520353656360243
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.057361525104486784
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.0727895384398315
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.09236708571873861
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.11721022975334805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.14873521072935117
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.18873918221350977
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.2395026619987486
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.3039195382313198
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.38566204211634725
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.02592943797404667, gamma=0.4893900918477494
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.02592943797404667, gamma=0.6210169418915616
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.02592943797404667, gamma=0.7880462815669912
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.02592943797404667, gamma=1.0
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.035622478902624426, gamma=0.001
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.0012689610031679222
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.0016102620275609393
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.0020433597178569417
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.002592943797404667
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.0032903445623126675
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.0041753189365604
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.005298316906283708
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.006723357536499335
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.008531678524172805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.010826367338740546
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.01373823795883263
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.017433288221999882
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# C=0.035622478902624426, gamma=0.022122162910704492
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.02807216203941177
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.035622478902624426
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.04520353656360243
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.057361525104486784
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.0727895384398315
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.09236708571873861
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.11721022975334805
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.14873521072935117
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.18873918221350977
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.2395026619987486
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.035622478902624426, gamma=0.3039195382313198
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.035622478902624426, gamma=0.38566204211634725
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.035622478902624426, gamma=0.4893900918477494
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.035622478902624426, gamma=0.6210169418915616
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.035622478902624426, gamma=0.7880462815669912
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.035622478902624426, gamma=1.0
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=0.04893900918477494, gamma=0.001
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.04893900918477494, gamma=0.0012689610031679222
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.04893900918477494, gamma=0.0016102620275609393
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.04893900918477494, gamma=0.0020433597178569417
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.04893900918477494, gamma=0.002592943797404667
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.04893900918477494, gamma=0.0032903445623126675
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.04893900918477494, gamma=0.0041753189365604
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# C=0.04893900918477494, gamma=0.005298316906283708
# NER: 0.500, Sensitivity or recall: 1.000, Specificity: 0.000, Precision: 0.553, Correctly classified: 0.553, MCC: nan
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# <ipython-input-39-d75c9e15214a>:8: RuntimeWarning: invalid value encountered in true_divide
#   mcc = (tp*tn-fp*fn)/np.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
# ...
# C=38.56620421163472, gamma=0.18873918221350977
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=38.56620421163472, gamma=0.2395026619987486
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=38.56620421163472, gamma=0.3039195382313198
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=38.56620421163472, gamma=0.38566204211634725
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=38.56620421163472, gamma=0.4893900918477494
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=38.56620421163472, gamma=0.6210169418915616
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=38.56620421163472, gamma=0.7880462815669912
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=38.56620421163472, gamma=1.0
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.001
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.0012689610031679222
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.0016102620275609393
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.0020433597178569417
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.002592943797404667
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.0032903445623126675
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.0041753189365604
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.005298316906283708
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.006723357536499335
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.008531678524172805
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.010826367338740546
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.01373823795883263
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.017433288221999882
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.022122162910704492
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.02807216203941177
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.035622478902624426
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.04520353656360243
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.057361525104486784
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.0727895384398315
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.09236708571873861
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.11721022975334805
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.14873521072935117
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.18873918221350977
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.2395026619987486
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.3039195382313198
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.38566204211634725
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.4893900918477494
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.6210169418915616
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=0.7880462815669912
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=52.98316906283707, gamma=1.0
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.001
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.0012689610031679222
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.0016102620275609393
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.0020433597178569417
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.002592943797404667
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.0032903445623126675
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.0041753189365604
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.005298316906283708
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.006723357536499335
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.008531678524172805
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.010826367338740546
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.01373823795883263
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.017433288221999882
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.022122162910704492
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.02807216203941177
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.035622478902624426
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.04520353656360243
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.057361525104486784
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.0727895384398315
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.09236708571873861
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.11721022975334805
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.14873521072935117
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.18873918221350977
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.2395026619987486
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.3039195382313198
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.38566204211634725
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.4893900918477494
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.6210169418915616
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=0.7880462815669912
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=72.78953843983146, gamma=1.0
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.001
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.0012689610031679222
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.0016102620275609393
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.0020433597178569417
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.002592943797404667
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.0032903445623126675
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.0041753189365604
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.005298316906283708
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.006723357536499335
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.008531678524172805
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.010826367338740546
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.01373823795883263
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.017433288221999882
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.022122162910704492
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.02807216203941177
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.035622478902624426
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.04520353656360243
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.057361525104486784
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.0727895384398315
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.09236708571873861
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.11721022975334805
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.14873521072935117
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.18873918221350977
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.2395026619987486
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.3039195382313198
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.38566204211634725
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.4893900918477494
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.6210169418915616
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=0.7880462815669912
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163
# C=100.0, gamma=1.0
# NER: 0.581, Sensitivity or recall: 0.654, Specificity: 0.508, Precision: 0.622, Correctly classified: 0.589, MCC: 0.163

# %%
C=3.039195382313198
gamma=0.005298316906283708
svm_obj = SVC(C=C, kernel="rbf", gamma=gamma, class_weight="balanced")
MCC_val_all, MCC_test_all, acc_val_all, acc_test_all = run_cross_validation(best_features, active, folds=10, clf=svm_obj, verbose=False)

# %%
plot_results_CV(MCC_val_all, MCC_test_all, acc_val_all, acc_test_all)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, VotingClassifier

# %%
train_data, test_data, train_labels, test_labels = train_test_split(joined_features, active, test_size=0.25, random_state=42, stratify=active)

# %%
C= 0.788046
gamm = 0.0239502
svm = SVC(C=C, kernel="rbf", gamma=gamm, class_weight="balanced")
clf2 = RandomForestClassifier(n_estimators=100, random_state=42)
clf3 = GaussianNB()
eclf1 = VotingClassifier(estimators=[('svm', svm), ('rf', clf2), ('gnb', clf3)], voting='hard')
eclf1.fit(train_data, train_labels)
predictions = eclf1.predict(test_data)
vals = print_metrics(predictions, test_labels)
plot_confusion(predictions, test_labels)
# Out:
# NER: 0.773, Sensitivity or recall: 0.974, Specificity: 0.571, Precision: 0.738, Correctly classified: 0.794, MCC: 0.612

# %%
MCC_val_vote, MCC_test_vote, acc_val_vote, acc_test_vote = run_cross_validation(best_features, active, folds=10, clf=eclf1, verbose=False)

# %%
plot_results_CV(MCC_val_vote, MCC_test_vote, acc_val_vote, acc_test_vote)
